# %% [markdown]
# # Preprocessing Kecelakaan
#
# Anggota:
# - Ahmad Danindra Nugroho (5025211259)
# - Muhammad Ghifari Taqiuddin (5025211063)
# - Raihan Farid (5025201141)
# - Talitha Hayyinas Sahala (5025211263)

# %% [markdown]
# # Preparations

# %%
# Installing dependencies
# Only run once
# %pip install gnews nlp-id PySastrawi pillow matplotlib numpy wordcloud pandas
# Out:
# Requirement already satisfied: gnews in d:\anaconda3\envs\textmining\lib\site-packages (0.3.6)
# Requirement already satisfied: nlp-id in d:\anaconda3\envs\textmining\lib\site-packages (0.1.15.0)
# Requirement already satisfied: PySastrawi in d:\anaconda3\envs\textmining\lib\site-packages (1.2.0)
# Requirement already satisfied: pillow in d:\anaconda3\envs\textmining\lib\site-packages (10.2.0)
# Requirement already satisfied: matplotlib in d:\anaconda3\envs\textmining\lib\site-packages (3.8.3)
# Requirement already satisfied: numpy in d:\anaconda3\envs\textmining\lib\site-packages (1.24.3)
# Requirement already satisfied: wordcloud in d:\anaconda3\envs\textmining\lib\site-packages (1.9.3)
# Requirement already satisfied: pandas in d:\anaconda3\envs\textmining\lib\site-packages (2.2.1)
# Requirement already satisfied: feedparser~=6.0.2 in d:\anaconda3\envs\textmining\lib\site-packages (from gnews) (6.0.11)
# Requirement already satisfied: bs4~=0.0.1 in d:\anaconda3\envs\textmining\lib\site-packages (from gnews) (0.0.2)
# Requirement already satisfied: beautifulsoup4~=4.9.3 in d:\anaconda3\envs\textmining\lib\site-packages (from gnews) (4.9.3)
# Requirement already satisfied: pymongo~=3.12.0 in d:\anaconda3\envs\textmining\lib\site-packages (from gnews) (3.12.3)
# Requirement already satisfied: dnspython~=1.16.0 in d:\anaconda3\envs\textmining\lib\site-packages (from gnews) (1.16.0)
# Requirement already satisfied: python-dotenv~=0.19.0 in d:\anaconda3\envs\textmining\lib\site-packages (from gnews) (0.19.2)
# Requirement already satisfied: requests==2.26.0 in d:\anaconda3\envs\textmining\lib\site-packages (from gnews) (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\envs\textmining\lib\site-packages (from requests==2.26.0->gnews) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\textmining\lib\site-packages (from requests==2.26.0->gnews) (2024.2.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda3\envs\textmining\lib\site-packages (from requests==2.26.0->gnews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\textmining\lib\site-packages (from requests==2.26.0->gnews) (3.4)
# Requirement already satisfied: scikit-learn==1.2.2 in d:\anaconda3\envs\textmining\lib\site-packages (from nlp-id) (1.2.2)
# Requirement already satisfied: nltk==3.8.1 in d:\anaconda3\envs\textmining\lib\site-packages (from nlp-id) (3.8.1)
# Requirement already satisfied: wget==3.2 in d:\anaconda3\envs\textmining\lib\site-packages (from nlp-id) (3.2)
# Requirement already satisfied: pytest==7.3.1 in d:\anaconda3\envs\textmining\lib\site-packages (from nlp-id) (7.3.1)
# Requirement already satisfied: click in d:\anaconda3\envs\textmining\lib\site-packages (from nltk==3.8.1->nlp-id) (8.1.7)
# Requirement already satisfied: joblib in d:\anaconda3\envs\textmining\lib\site-packages (from nltk==3.8.1->nlp-id) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda3\envs\textmining\lib\site-packages (from nltk==3.8.1->nlp-id) (2023.12.25)
# Requirement already satisfied: tqdm in d:\anaconda3\envs\textmining\lib\site-packages (from nltk==3.8.1->nlp-id) (4.66.2)
# Requirement already satisfied: iniconfig in d:\anaconda3\envs\textmining\lib\site-packages (from pytest==7.3.1->nlp-id) (2.0.0)
# Requirement already satisfied: packaging in d:\anaconda3\envs\textmining\lib\site-packages (from pytest==7.3.1->nlp-id) (23.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in d:\anaconda3\envs\textmining\lib\site-packages (from pytest==7.3.1->nlp-id) (1.5.0)
# Requirement already satisfied: colorama in d:\anaconda3\envs\textmining\lib\site-packages (from pytest==7.3.1->nlp-id) (0.4.6)
# Requirement already satisfied: scipy>=1.3.2 in d:\anaconda3\envs\textmining\lib\site-packages (from scikit-learn==1.2.2->nlp-id) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda3\envs\textmining\lib\site-packages (from scikit-learn==1.2.2->nlp-id) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\envs\textmining\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\envs\textmining\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\envs\textmining\lib\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda3\envs\textmining\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda3\envs\textmining\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\envs\textmining\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\textmining\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda3\envs\textmining\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda3\envs\textmining\lib\site-packages (from beautifulsoup4~=4.9.3->gnews) (2.5)
# Requirement already satisfied: sgmllib3k in d:\anaconda3\envs\textmining\lib\site-packages (from feedparser~=6.0.2->gnews) (1.0.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\textmining\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import all dependencies
from nlp_id import tokenizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import os
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Directory for all related files
dataset_dir = '../dataset/'
os.makedirs(dataset_dir, exist_ok=True)

# %%
os.listdir(dataset_dir)
# Out:
# ['Banjir-2018-2023.csv',
#  'Gempa Bumi-2018-2023.csv',
#  'Kebakaran-2018-2023.csv',
#  'Kecelakaan-2018-2023.csv']

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv(os.path.join(dataset_dir, 'Kecelakaan-2018-2023.csv'))
df = df.drop(columns=['description' , 'url', 'publisher'])
df['title'] = df['title'].apply(lambda x: x.split(' - ')[0])
df = df[['published date', 'title']]
print(df.shape)
df.head()
# Out:
# (7200, 2)
#               published date  \
# 0  2018-01-01 08:00:00+00:00
# 1  2018-01-01 08:00:00+00:00
# 2  2018-01-01 08:00:00+00:00
# 3  2018-01-01 08:00:00+00:00
# 4  2018-01-01 08:00:00+00:00
#
#                                                title
# 0  CEO Inggris turut tewas dalam kecelakaan pesaw...
# 1  Benarkah Bulan Purnama dan Supermoon Sebabkan ...
# 2  Kecelakaan di Indrapuri, Korban Mahasiswi Asal...
# 3  Menguak Alasan Wanita Lebih Rentan Kecelakaan ...
# 4  Dua belas orang tewas dalam kecelakaan pesawat...

# %% [markdown]
# ## Preprocessing
#
# 1. Casefolding: mengubah semua karakter huruf ke huruf kecil
# 2. Stemming: mengubah suatu kata menjadi bentuk dasarnya (mengatakan -> kata)
# 3. Tokenization: memecah kalimat menjadi beberapa token
# 4. Stopwords Removal: memfilter kata yang sering muncul tapi tidak berpengaruh dalam pemrosesan (tergantung umumnya konjungsi, preposisi, pronomina, dsb.)

# %%
# 1. Casefolding
df['title'] = df['title'].str.lower()
df.head()
# Out:
#               published date  \
# 0  2018-01-01 08:00:00+00:00
# 1  2018-01-01 08:00:00+00:00
# 2  2018-01-01 08:00:00+00:00
# 3  2018-01-01 08:00:00+00:00
# 4  2018-01-01 08:00:00+00:00
#
#                                                title
# 0  ceo inggris turut tewas dalam kecelakaan pesaw...
# 1  benarkah bulan purnama dan supermoon sebabkan ...
# 2  kecelakaan di indrapuri, korban mahasiswi asal...
# 3  menguak alasan wanita lebih rentan kecelakaan ...
# 4  dua belas orang tewas dalam kecelakaan pesawat...

# %%
# 2. Stemming
# Menggunakan stemmer dari library PySastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

df['stem'] = df['title'].apply(stemmer.stem)
df.head()
# Out:
#               published date  \
# 0  2018-01-01 08:00:00+00:00
# 1  2018-01-01 08:00:00+00:00
# 2  2018-01-01 08:00:00+00:00
# 3  2018-01-01 08:00:00+00:00
# 4  2018-01-01 08:00:00+00:00
#
#                                                title  \
# 0  ceo inggris turut tewas dalam kecelakaan pesaw...
# 1  benarkah bulan purnama dan supermoon sebabkan ...
# 2  kecelakaan di indrapuri, korban mahasiswi asal...
# 3  menguak alasan wanita lebih rentan kecelakaan ...
# 4  dua belas orang tewas dalam kecelakaan pesawat...
#
#                                                 stem
# 0  ceo inggris turut tewas dalam celaka pesawat s...
# 1     benar bulan purnama dan supermoon sebab celaka
# 2  celaka di indrapuri korban mahasiswi asal aceh...
# 3    uak alas wanita lebih rentan celaka saat kemudi
# 4  dua belas orang tewas dalam celaka pesawat di ...

# %%
# 3. Tokenization
# Menggunakan tokenizer dari library nlp-id
tok = tokenizer.Tokenizer()

# df['tokens'] = df['stem'].apply(tok.tokenize)
df['tokens'] = df['stem'].apply(tok.tokenize)
df.head()
# Out:
#               published date  \
# 0  2018-01-01 08:00:00+00:00
# 1  2018-01-01 08:00:00+00:00
# 2  2018-01-01 08:00:00+00:00
# 3  2018-01-01 08:00:00+00:00
# 4  2018-01-01 08:00:00+00:00
#
#                                                title  \
# 0  ceo inggris turut tewas dalam kecelakaan pesaw...
# 1  benarkah bulan purnama dan supermoon sebabkan ...
# 2  kecelakaan di indrapuri, korban mahasiswi asal...
# 3  menguak alasan wanita lebih rentan kecelakaan ...
# 4  dua belas orang tewas dalam kecelakaan pesawat...
#
#                                                 stem  \
# 0  ceo inggris turut tewas dalam celaka pesawat s...
# 1     benar bulan purnama dan supermoon sebab celaka
# 2  celaka di indrapuri korban mahasiswi asal aceh...
# 3    uak alas wanita lebih rentan celaka saat kemudi
# 4  dua belas orang tewas dalam celaka pesawat di ...
#
#                                               tokens
# 0  [ceo, inggris, turut, tewas, dalam, celaka, pe...
# 1  [benar, bulan, purnama, dan, supermoon, sebab,...
# 2  [celaka, di, indrapuri, korban, mahasiswi, asa...
# 3  [uak, alas, wanita, lebih, rentan, celaka, saa...
# 4  [dua, belas, orang, tewas, dalam, celaka, pesa...

# %%
# 4. Stopwords removal
# Menggunakan list stopwords dari library nltk
list_stopwords = set(stopwords.words('indonesian'))

def remove_stopwords(tokens):
    return [word for word in tokens if word not in list_stopwords]

df['tokens_clean'] = df['tokens'].apply(remove_stopwords)
df.head()
# Out:
#               published date  \
# 0  2018-01-01 08:00:00+00:00
# 1  2018-01-01 08:00:00+00:00
# 2  2018-01-01 08:00:00+00:00
# 3  2018-01-01 08:00:00+00:00
# 4  2018-01-01 08:00:00+00:00
#
#                                                title  \
# 0  ceo inggris turut tewas dalam kecelakaan pesaw...
# 1  benarkah bulan purnama dan supermoon sebabkan ...
# 2  kecelakaan di indrapuri, korban mahasiswi asal...
# 3  menguak alasan wanita lebih rentan kecelakaan ...
# 4  dua belas orang tewas dalam kecelakaan pesawat...
#
#                                                 stem  \
# 0  ceo inggris turut tewas dalam celaka pesawat s...
# 1     benar bulan purnama dan supermoon sebab celaka
# 2  celaka di indrapuri korban mahasiswi asal aceh...
# 3    uak alas wanita lebih rentan celaka saat kemudi
# 4  dua belas orang tewas dalam celaka pesawat di ...
#
#                                               tokens  \
# 0  [ceo, inggris, turut, tewas, dalam, celaka, pe...
# 1  [benar, bulan, purnama, dan, supermoon, sebab,...
# 2  [celaka, di, indrapuri, korban, mahasiswi, asa...
# 3  [uak, alas, wanita, lebih, rentan, celaka, saa...
# 4  [dua, belas, orang, tewas, dalam, celaka, pesa...
#
#                                         tokens_clean
# 0     [ceo, inggris, tewas, celaka, pesawat, sydney]
# 1                       [purnama, supermoon, celaka]
# 2  [celaka, indrapuri, korban, mahasiswi, aceh, t...
# 3        [uak, alas, wanita, rentan, celaka, kemudi]
# 4  [belas, orang, tewas, celaka, pesawat, kosta, ...

# %%
# Gabungkan kembali token pada kolom 'tokens_clean'
df['merged'] = df['tokens_clean'].apply(lambda token: ' '.join(token))
df.head()
# Out:
#               published date  \
# 0  2018-01-01 08:00:00+00:00
# 1  2018-01-01 08:00:00+00:00
# 2  2018-01-01 08:00:00+00:00
# 3  2018-01-01 08:00:00+00:00
# 4  2018-01-01 08:00:00+00:00
#
#                                                title  \
# 0  ceo inggris turut tewas dalam kecelakaan pesaw...
# 1  benarkah bulan purnama dan supermoon sebabkan ...
# 2  kecelakaan di indrapuri, korban mahasiswi asal...
# 3  menguak alasan wanita lebih rentan kecelakaan ...
# 4  dua belas orang tewas dalam kecelakaan pesawat...
#
#                                                 stem  \
# 0  ceo inggris turut tewas dalam celaka pesawat s...
# 1     benar bulan purnama dan supermoon sebab celaka
# 2  celaka di indrapuri korban mahasiswi asal aceh...
# 3    uak alas wanita lebih rentan celaka saat kemudi
# 4  dua belas orang tewas dalam celaka pesawat di ...
#
#                                               tokens  \
# 0  [ceo, inggris, turut, tewas, dalam, celaka, pe...
# 1  [benar, bulan, purnama, dan, supermoon, sebab,...
# 2  [celaka, di, indrapuri, korban, mahasiswi, asa...
# 3  [uak, alas, wanita, lebih, rentan, celaka, saa...
# 4  [dua, belas, orang, tewas, dalam, celaka, pesa...
#
#                                         tokens_clean  \
# 0     [ceo, inggris, tewas, celaka, pesawat, sydney]
# 1                       [purnama, supermoon, celaka]
# 2  [celaka, indrapuri, korban, mahasiswi, aceh, t...
# 3        [uak, alas, wanita, rentan, celaka, kemudi]
# 4  [belas, orang, tewas, celaka, pesawat, kosta, ...
#
#                                               merged
# 0            ceo inggris tewas celaka pesawat sydney
# 1                           purnama supermoon celaka
# 2  celaka indrapuri korban mahasiswi aceh tamiang...
# 3               uak alas wanita rentan celaka kemudi
# 4        belas orang tewas celaka pesawat kosta rika

# %% [markdown]
# Drop Useless Data

# %%
df.drop(df[df['title'] == 'video'].index, inplace=True)

# %% [markdown]
# ## Visualisasi WordCloud
#
# Pembanding data antara sebelum dan setelah dilakukan pra-pemrosesan

# %%
text_before = ' '.join(df['title'].tolist())
wordcloud_before = WordCloud(background_color='white', collocations=False).generate(text_before)

plt.imshow(wordcloud_before)
plt.axis("off")
plt.show()

# %%
text_after = ' '.join(df['merged'])
wordcloud_after = WordCloud(background_color='white', collocations=False).generate(text_after)

plt.imshow(wordcloud_after)
plt.axis("off")
plt.show()

# %%
# Simpan output ke dalam CSV
df.to_csv('Kecelakaan-2018-2023-pre.csv', index=False)
