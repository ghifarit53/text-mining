# %% [markdown]
# # Preprocessing Gempa Bumi
#
# Anggota:
# - Ahmad Danindra Nugroho (5025211259)
# - Muhammad Ghifari Taqiuddin (5025211063)
# - Raihan Farid (5025201141)
# - Talitha Hayyinas Sahala (5025211263)

# %% [markdown]
# # Preparations

# %%
# Installing dependencies
# Only run once
# %pip install gnews nlp-id PySastrawi pillow matplotlib numpy wordcloud pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gnews in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (0.3.6)
# Requirement already satisfied: nlp-id in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (0.1.15.0)
# Requirement already satisfied: PySastrawi in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (1.2.0)
# Requirement already satisfied: pillow in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (10.0.1)
# Requirement already satisfied: matplotlib in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (3.8.0)
# Requirement already satisfied: numpy in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (1.26.0)
# Requirement already satisfied: wordcloud in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (1.9.3)
# Requirement already satisfied: pandas in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (2.1.0)
# Requirement already satisfied: pymongo~=3.12.0 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from gnews) (3.12.3)
# Requirement already satisfied: beautifulsoup4~=4.9.3 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from gnews) (4.9.3)
# Requirement already satisfied: python-dotenv~=0.19.0 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from gnews) (0.19.2)
# Requirement already satisfied: bs4~=0.0.1 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from gnews) (0.0.2)
# Requirement already satisfied: dnspython~=1.16.0 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from gnews) (1.16.0)
# Requirement already satisfied: requests==2.26.0 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from gnews) (2.26.0)
# Requirement already satisfied: feedparser~=6.0.2 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from gnews) (6.0.11)
# Requirement already satisfied: idna<4,>=2.5 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from requests==2.26.0->gnews) (3.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from requests==2.26.0->gnews) (1.26.18)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from requests==2.26.0->gnews) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from requests==2.26.0->gnews) (2024.2.2)
# Requirement already satisfied: nltk==3.8.1 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from nlp-id) (3.8.1)
# Requirement already satisfied: scikit-learn==1.2.2 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from nlp-id) (1.2.2)
# Requirement already satisfied: pytest==7.3.1 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from nlp-id) (7.3.1)
# Requirement already satisfied: wget==3.2 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from nlp-id) (3.2)
# Requirement already satisfied: click in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from nltk==3.8.1->nlp-id) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from nltk==3.8.1->nlp-id) (2024.4.28)
# Requirement already satisfied: joblib in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from nltk==3.8.1->nlp-id) (1.4.0)
# Requirement already satisfied: tqdm in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from nltk==3.8.1->nlp-id) (4.66.2)
# Requirement already satisfied: tomli>=1.0.0 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from pytest==7.3.1->nlp-id) (2.0.1)
# Requirement already satisfied: iniconfig in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from pytest==7.3.1->nlp-id) (2.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from pytest==7.3.1->nlp-id) (1.2.1)
# Requirement already satisfied: packaging in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from pytest==7.3.1->nlp-id) (23.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from pytest==7.3.1->nlp-id) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from scikit-learn==1.2.2->nlp-id) (3.5.0)
# Requirement already satisfied: scipy>=1.3.2 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from scikit-learn==1.2.2->nlp-id) (1.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.0.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: soupsieve>1.2 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4~=4.9.3->gnews) (2.5)
# Requirement already satisfied: sgmllib3k in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from feedparser~=6.0.2->gnews) (1.0.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/talithahayyinassahala/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.16.2)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import all dependencies
from nlp_id import tokenizer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas as pd
import os

# %%
# Directory for all related files
dataset_dir = '../dataset/'
os.makedirs(dataset_dir, exist_ok=True)

# %%
os.listdir(dataset_dir)
# Out:
# ['Gempa Bumi-2018-2023.csv',
#  'Kebakaran-2018-2023.csv',
#  'Banjir-2018-2023.csv',
#  'Kecelakaan-2018-2023.csv']

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv(os.path.join(dataset_dir, 'Gempa Bumi-2018-2023.csv'))
df = df.drop(columns=['description' , 'url', 'publisher'])
df['title'] = df['title'].apply(lambda x: x.split(' - ')[0])
df = df[['published date', 'title']]
print(df.shape)
df.head()
# Out:
# (6039, 2)
#               published date                                     title
# 0  2018-01-11 08:00:00+00:00        Gempa bumi 5,1 SR mengguncang Iran
# 1  2018-01-12 08:00:00+00:00  Gempa Tektonik 4 SR Guncang Nias Selatan
# 2  2018-01-12 08:00:00+00:00     Gempa bumi guncang wilayah Luwu Timur
# 3  2018-01-18 08:00:00+00:00   5 Meteor yang Pernah Jatuh di Indonesia
# 4  2018-01-20 10:32:09+00:00               Gerak Cepat Tanpa Pembedaan

# %% [markdown]
# ## Preprocessing
#
# 1. Casefolding: mengubah semua karakter huruf ke huruf kecil
# 2. Stemming: mengubah suatu kata menjadi bentuk dasarnya (mengatakan -> kata)
# 3. Tokenization: memecah kalimat menjadi beberapa token
# 4. Stopwords Removal: memfilter kata yang sering muncul tapi tidak berpengaruh dalam pemrosesan (tergantung umumnya konjungsi, preposisi, pronomina, dsb.)

# %%
# 1. Casefolding
df['title'] = df['title'].str.lower()
df.head()
# Out:
#               published date                                     title
# 0  2018-01-11 08:00:00+00:00        gempa bumi 5,1 sr mengguncang iran
# 1  2018-01-12 08:00:00+00:00  gempa tektonik 4 sr guncang nias selatan
# 2  2018-01-12 08:00:00+00:00     gempa bumi guncang wilayah luwu timur
# 3  2018-01-18 08:00:00+00:00   5 meteor yang pernah jatuh di indonesia
# 4  2018-01-20 10:32:09+00:00               gerak cepat tanpa pembedaan

# %%
# 2. Stemming
# Menggunakan stemmer dari library PySastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

df['stem'] = df['title'].apply(stemmer.stem)
df.head()
# Out:
#               published date                                     title  \
# 0  2018-01-11 08:00:00+00:00        gempa bumi 5,1 sr mengguncang iran
# 1  2018-01-12 08:00:00+00:00  gempa tektonik 4 sr guncang nias selatan
# 2  2018-01-12 08:00:00+00:00     gempa bumi guncang wilayah luwu timur
# 3  2018-01-18 08:00:00+00:00   5 meteor yang pernah jatuh di indonesia
# 4  2018-01-20 10:32:09+00:00               gerak cepat tanpa pembedaan
#
#                                        stem
# 0            gempa bumi 5 1 sr guncang iran
# 1  gempa tektonik 4 sr guncang nias selatan
# 2     gempa bumi guncang wilayah luwu timur
# 3   5 meteor yang pernah jatuh di indonesia
# 4                    gerak cepat tanpa beda

# %%
# 3. Tokenization
# Menggunakan tokenizer dari library nlp-id
tok = tokenizer.Tokenizer()

df['tokens'] = df['stem'].apply(tok.tokenize)
df.head()
# Out:
#               published date                                     title  \
# 0  2018-01-11 08:00:00+00:00        gempa bumi 5,1 sr mengguncang iran
# 1  2018-01-12 08:00:00+00:00  gempa tektonik 4 sr guncang nias selatan
# 2  2018-01-12 08:00:00+00:00     gempa bumi guncang wilayah luwu timur
# 3  2018-01-18 08:00:00+00:00   5 meteor yang pernah jatuh di indonesia
# 4  2018-01-20 10:32:09+00:00               gerak cepat tanpa pembedaan
#
#                                        stem  \
# 0            gempa bumi 5 1 sr guncang iran
# 1  gempa tektonik 4 sr guncang nias selatan
# 2     gempa bumi guncang wilayah luwu timur
# 3   5 meteor yang pernah jatuh di indonesia
# 4                    gerak cepat tanpa beda
#
#                                              tokens
# 0            [gempa, bumi, 5, 1, sr, guncang, iran]
# 1  [gempa, tektonik, 4, sr, guncang, nias, selatan]
# 2      [gempa, bumi, guncang, wilayah, luwu, timur]
# 3   [5, meteor, yang, pernah, jatuh, di, indonesia]
# 4                       [gerak, cepat, tanpa, beda]

# %%
# 4. Stopwords removal
# Menggunakan list stopwords dari library nltk
list_stopwords = set(stopwords.words('indonesian'))


def remove_stopwords(tokens):
    return [word for word in tokens if word not in list_stopwords]

keywords = ['tips']
mask = df['title'].str.contains('|'.join(keywords), case=False)
df = df[~mask]

# Apply remove_stopwords function to clean tokens
def remove_stopwords(tokens):
    return [word for word in tokens if word not in list_stopwords]

df['tokens_clean'] = df['tokens'].apply(remove_stopwords)
df.head()
# Out:
#               published date                                     title  \
# 0  2018-01-11 08:00:00+00:00        gempa bumi 5,1 sr mengguncang iran
# 1  2018-01-12 08:00:00+00:00  gempa tektonik 4 sr guncang nias selatan
# 2  2018-01-12 08:00:00+00:00     gempa bumi guncang wilayah luwu timur
# 3  2018-01-18 08:00:00+00:00   5 meteor yang pernah jatuh di indonesia
# 4  2018-01-20 10:32:09+00:00               gerak cepat tanpa pembedaan
#
#                                        stem  \
# 0            gempa bumi 5 1 sr guncang iran
# 1  gempa tektonik 4 sr guncang nias selatan
# 2     gempa bumi guncang wilayah luwu timur
# 3   5 meteor yang pernah jatuh di indonesia
# 4                    gerak cepat tanpa beda
#
#                                              tokens  \
# 0            [gempa, bumi, 5, 1, sr, guncang, iran]
# 1  [gempa, tektonik, 4, sr, guncang, nias, selatan]
# 2      [gempa, bumi, guncang, wilayah, luwu, timur]
# 3   [5, meteor, yang, pernah, jatuh, di, indonesia]
# 4                       [gerak, cepat, tanpa, beda]
#
#                                        tokens_clean
# 0            [gempa, bumi, 5, 1, sr, guncang, iran]
# 1  [gempa, tektonik, 4, sr, guncang, nias, selatan]
# 2      [gempa, bumi, guncang, wilayah, luwu, timur]
# 3                     [5, meteor, jatuh, indonesia]
# 4                              [gerak, cepat, beda]

# %%
df[df['title'].str.contains("tips")]
# Out:
# Empty DataFrame
# Columns: [published date, title, stem, tokens, tokens_clean]
# Index: []

# %%
# Define the values to remove
values_to_remove = ['benarkah gempa besar selalu terjadi saat purnama?,benar gempa besar selalu jadi saat purnama', 'ingat, enam hal yang sebaiknya kamu lakukan saat terjadi gempa bumi, no 6 jangan sampai lupa",ingat enam hal yang baik kamu laku saat jadi gempa bumi no 6 jangan sampai lupa,']

# Check whether each row's value matches any of the removal values
condition = df['title'].isin(values_to_remove)

# Drop the matching rows from the original DataFrame
df.drop(df[condition].index, inplace=True)

# %%
# Mengecek jumlah data dalam DataFrame
jumlah_data = df.shape[0]
print("Jumlah data dalam DataFrame adalah:", jumlah_data)
# Out:
# Jumlah data dalam DataFrame adalah: 6023

# %%
# Gabungkan kembali token pada kolom 'tokens_clean'
df['merged'] = df['tokens_clean'].apply(lambda token: ' '.join(token))
df.head()
# Out:
#               published date                                     title  \
# 0  2018-01-11 08:00:00+00:00        gempa bumi 5,1 sr mengguncang iran
# 1  2018-01-12 08:00:00+00:00  gempa tektonik 4 sr guncang nias selatan
# 2  2018-01-12 08:00:00+00:00     gempa bumi guncang wilayah luwu timur
# 3  2018-01-18 08:00:00+00:00   5 meteor yang pernah jatuh di indonesia
# 4  2018-01-20 10:32:09+00:00               gerak cepat tanpa pembedaan
#
#                                        stem  \
# 0            gempa bumi 5 1 sr guncang iran
# 1  gempa tektonik 4 sr guncang nias selatan
# 2     gempa bumi guncang wilayah luwu timur
# 3   5 meteor yang pernah jatuh di indonesia
# 4                    gerak cepat tanpa beda
#
#                                              tokens  \
# 0            [gempa, bumi, 5, 1, sr, guncang, iran]
# 1  [gempa, tektonik, 4, sr, guncang, nias, selatan]
# 2      [gempa, bumi, guncang, wilayah, luwu, timur]
# 3   [5, meteor, yang, pernah, jatuh, di, indonesia]
# 4                       [gerak, cepat, tanpa, beda]
#
#                                        tokens_clean  \
# 0            [gempa, bumi, 5, 1, sr, guncang, iran]
# 1  [gempa, tektonik, 4, sr, guncang, nias, selatan]
# 2      [gempa, bumi, guncang, wilayah, luwu, timur]
# 3                     [5, meteor, jatuh, indonesia]
# 4                              [gerak, cepat, beda]
#
#                                      merged
# 0            gempa bumi 5 1 sr guncang iran
# 1  gempa tektonik 4 sr guncang nias selatan
# 2     gempa bumi guncang wilayah luwu timur
# 3                  5 meteor jatuh indonesia
# 4                          gerak cepat beda

# %% [markdown]
# ## Visualisasi WordCloud
#
# Pembanding data antara sebelum dan setelah dilakukan pra-pemrosesan

# %%
text_before = ' '.join(df['stem'].tolist())
wordcloud_before = WordCloud(background_color='white', collocations=False).generate(text_before)

plt.imshow(wordcloud_before)
plt.axis("off")
plt.show()

# %%
text_after = ' '.join(df['merged'])
wordcloud_after = WordCloud(background_color='white', collocations=False).generate(text_after)

plt.imshow(wordcloud_after)
plt.axis("off")
plt.show()

# %%
# Simpan output ke dalam CSV
df.to_csv('Gempa Bumi-2018-2023-pre.csv', index=False)
